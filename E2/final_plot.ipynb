# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from matplotlib.ticker import NullFormatter
plt.rcParams['font.size'] = 14
# from IPython.display import display_html

# %%
dir_name = "My_data_results_FINALE_2hidden_fin/"
Number_of_files = 5
best = "Adam_20_one_hot_NO-Spin"
file_name = dir_name + best

cols=["epochs", "energy", "A_S", "A_T", "score", "entropy", "log_likelihood"]
df = pd.DataFrame(columns=cols)

for i in range(1, Number_of_files+1):
    read_result = pd.read_csv(file_name+"_"+str(i)+".dat", delimiter=" ", names=cols, header=0)
    df = df.append(read_result, ignore_index=True)
# Out:
# C:\Users\ricta\AppData\Local\Temp\ipykernel_1604\1764210449.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_result, ignore_index=True)
# C:\Users\ricta\AppData\Local\Temp\ipykernel_1604\1764210449.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_result, ignore_index=True)
# C:\Users\ricta\AppData\Local\Temp\ipykernel_1604\1764210449.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_result, ignore_index=True)
# C:\Users\ricta\AppData\Local\Temp\ipykernel_1604\1764210449.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df
# Out:
#      epochs        energy      A_S      A_T   score   entropy  log_likelihood
# 0       0.0  5.159300e-02  0.49200  0.72700  0.0592 -0.070465       -8.182945
# 1       1.0  4.526276e-02  0.49200  0.71260  0.0672 -0.073506       -8.006116
# 2       2.0  3.712025e-02  0.49200  0.69250  0.1007 -0.072913       -7.546263
# 3       3.0  2.391880e-02  0.49200  0.65445  0.1851 -0.073342       -6.866477
# 4       4.0  9.365013e-03  0.49210  0.59645  0.3262 -0.060713       -6.181246
# ..      ...           ...      ...      ...     ...       ...             ...
# 495    95.0  2.125000e-07  0.49990  0.50045  0.7874 -0.009200       -5.171004
# 496    96.0  1.105000e-06  0.49995  0.50105  0.7920 -0.001693       -5.163433
# 497    97.0  6.925000e-07  0.50070  0.50045  0.7896 -0.002138       -5.165154
# 498    98.0  1.772500e-06  0.50075  0.50110  0.7849 -0.002671       -5.175786
# 499    99.0  1.862500e-06  0.50065  0.50120  0.7887 -0.002716       -5.171948
#
# [500 rows x 7 columns]

# %%
res_mean = df.groupby(["epochs"]).mean()    # mean values
res_std = df.groupby(["epochs"]).std()      # error bars

# %%
# res_mean

# %%
plt.figure(figsize=(8,8))
plt.tight_layout()
color = "cornflowerblue"
err_color = "royalblue"
var = "energy"
# plot of the AAI index
plt.plot(df["epochs"].unique(), res_mean[var], label='AAI', ls="--", marker="o", color=color)
plt.errorbar(df["epochs"].unique(), res_mean[var], yerr=res_std[var], fmt='.', capsize=1, color=err_color)
plt.xlabel("# epochs")
plt.ylabel("Energy")
plt.legend()
plt.grid()
# plt.savefig("energy.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.tight_layout()
color1 = "cornflowerblue"
err_color1 = "royalblue"
color2 = "tomato"
err_color2 = "coral"
var1 = "A_S"
var2 = "A_T"
# plot of the AAI index
plt.plot(df["epochs"].unique(), res_mean[var1], label=var1, ls="--", marker="o", color=color1)
plt.errorbar(df["epochs"].unique(), res_mean[var1], yerr=res_std[var1], fmt='.', capsize=1, color=err_color1)
plt.plot(df["epochs"].unique(), res_mean[var2], label=var2, ls="--", marker="o", color=color2)
plt.errorbar(df["epochs"].unique(), res_mean[var2], yerr=res_std[var2], fmt='.', capsize=1, color=err_color2)
plt.xlabel("# epochs")
plt.ylabel("A")
plt.legend()
plt.grid()
# plt.savefig("energy.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.tight_layout()
color = "cornflowerblue"
err_color = "royalblue"
var = "score"
# plot of the AAI index
plt.plot(df["epochs"].unique(), res_mean[var], label='Our_score', ls="--", marker="o", color=color)
plt.errorbar(df["epochs"].unique(), res_mean[var], yerr=res_std[var], fmt='.', capsize=1, color=err_color)
plt.xlabel("# epochs")
plt.ylabel("Our score")
plt.legend()
plt.grid()
# plt.savefig("energy.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.tight_layout()
color = "cornflowerblue"
err_color = "royalblue"
var = "entropy"
# plot of the AAI index
plt.plot(df["epochs"].unique(), res_mean[var], label='Entropy', ls="--", marker="o", color=color)
plt.errorbar(df["epochs"].unique(), res_mean[var], yerr=res_std[var], fmt='.', capsize=1, color=err_color)
plt.xlabel("# epochs")
plt.ylabel("Entropy")
plt.legend()
plt.grid()
# plt.savefig("energy.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.tight_layout()
color = "cornflowerblue"
err_color = "royalblue"
var = "log_likelihood"
# plot of the AAI index
plt.plot(df["epochs"].unique(), res_mean[var], label='Log-likelihood', ls="--", marker="o", color=color)
plt.errorbar(df["epochs"].unique(), res_mean[var], yerr=res_std[var], fmt='.', capsize=1, color=err_color)
plt.xlabel("# epochs")
plt.ylabel("Log-likelihood")
plt.legend()
plt.grid()
# plt.savefig("energy.png", dpi=300)
plt.show()
